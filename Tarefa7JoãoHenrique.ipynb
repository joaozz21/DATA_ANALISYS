# %% [markdown]
# <a href="https://colab.research.google.com/github/joaozz21/Projetos_de_Estudo/blob/main/Tarefa7Jo%C3%A3oHenrique.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##João Henrique Alves de Oliveira Figueiredo

# %% [markdown]
# **1)** Faça a aproximação de $\pi$ usando a fórmula de Leibniz:
#
# $$\pi \approx 4 - \frac{4}{3} + \frac{4}{5} - \frac{4}{7} + \frac{4}{9}+...$$
#
# Calcule (e mostre na tela) a aproximação de $\pi$ considerando a) 50 termos, b) 500 termos, c) 1000 termos e d) 10000 termos.
#
# Dica: Note que o sinal do termo muda a cada termo. Talvez verificar se o $i$ é par ou ímpar ajude a decidir se para aquele i o sinal é mais ou menos.

# %%
def leibniz(termos:int):
  x = 4
  denominador = 1
  leibniz = 0
  i = 0

  while i <= termos:
    formula = x/denominador
    eibniz =leibniz + formula
    denominador += 2
    x = x*(-1)
    i+= 1

  return leibniz


termos50 = leibniz(50)
termos500 = leibniz(500)
termos1000 = leibniz(1000)
termos10000 = leibniz(10000)

print(f'Calculo de Leibniz com 50 termos: {termos50}')
print(f'Calculo de Leibniz com 500 termos: {termos500}')
print(f'Calculo de Leibniz com 1000 termos: {termos1000}')
print(f'Calculo de Leibniz com 10000 termos: {termos10000}')
# Out:
# Calculo de Leibniz com 50 termos: 3.1611986129870506
# Calculo de Leibniz com 500 termos: 3.143588659585789
# Calculo de Leibniz com 1000 termos: 3.1425916543395442
# Calculo de Leibniz com 10000 termos: 3.1416926435905346

# %% [markdown]
# **2)** O valor de $\ln(1+x)$ pode ser aproximado por (apenas para $|x|<1$):
#
# $\ln(1+x) = x - \frac{x^2}{2} + \frac{x^3}{3} ... = \displaystyle\sum_{i=1}^n (-1)^{i+1}\frac{x^i}{i} $
#
# $\ln$ é o logaritmo na base $e$ (conhecido como logaritmo natural).
#
# Use a expressão acima com n = 100 para encontrar $\ln(0.5)$.
#
# Compare o resultado com a função do Numpy `np.log(0.5)`.

# %%
import numpy as np

i=1
somatorio = 0

while i <= 100:
  somatorio += (-1**(i+1))*((0.5**i)/i)
  i += 1

print(f'Utilizando a fórmula: {somatorio}')
print(f'Utilizando Numpy: {np.log(0.5)}')
# Out:
# Utilizando a fórmula: -0.6931471805599451
# Utilizando Numpy: -0.6931471805599453

# %% [markdown]
# **3)** Calcular a aproximação de uma onda quadrada seguindo a seguinte expressão (a expressão abaixo é calculada utilizando uma teoria matemática conhecida como série de Fourier):
#
# $$x(t)  \approx \frac{4}{\pi}\displaystyle \sum_{i = 1}^N \frac{\sin\left[(2i - 1)t\right]}{2i - 1}$$
#
# Faça a aproximação para $0 \leqslant t \leqslant 10$ (utilize um número suficiente de pontos no vetor $t$ para poder observar o gráfico de $x(t)$, algo em torno de 100000 pontos).
#
# Faça a aproximação para a) N = 10, b) N = 100, c) N = 1000 e d) N = 10000. Coloque todas as aproximações em um único gráfico, com a aproximação de $x(t)$ em função de $t$.

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0,10,200000)

def fourier(termos:int):
  i = 1
  somatorio = 0

  while i <= termos:
    somatorio += (np.sin((2*i-1)*t))/(2*i)-1
    i+= 1

  fourier = (4/np.pi)*somatorio
  return fourier

plt.figure(figsize = (12,6))
plt.plot(t,fourier(10),label='1000 termos')
plt.plot(t,fourier(100),label='100 termos')
plt.plot(t,fourier(1000),label='10 termos')
plt.plot(t,fourier(10000),label='1 termos')
plt.legend()
plt.xlabel('t')
plt.ylabel('x(t)')
plt.grid()
plt.show()
