# %% [markdown]
# <a href="https://colab.research.google.com/github/joaozz21/Projetos_de_Estudo/blob/main/Aproxima%C3%A7%C3%A3o_de_uma_onda_quadrada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # João Henrique Alves de Oliveira

# %% [markdown]
# Calcular a aproximação de uma onda quadrada seguindo a seguinte expressão (a expressão abaixo é calculada utilizando uma teoria matemática conhecida como série de Fourier):
#
# $$x(t)  \approx \frac{4}{\pi}\displaystyle \sum_{i = 1}^N \frac{\sin\left[(2i - 1)t\right]}{2i - 1}$$
#
# Faça a aproximação para $0 \leqslant t \leqslant 10$ (utilize um número suficiente de pontos no vetor $t$ para poder observar o gráfico de $x(t)$, algo em torno de 100000 pontos).
#
# Faça a aproximação para N = 10 e coloque em um único gráfico, com a aproximação de $x(t)$ em função de $t$.

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0,10,100000)

def fourier(termos:int):
  i = 1
  somatorio = 0

  while i <= termos:
    somatorio += (np.sin((2*i-1)*t))/2*i-1
    i+= 1
  fourier = 4/np.pi*somatorio
  return fourier

plt.figure()
plt.plot(t,fourier(10),label='10 termos')
plt.legend()
plt.title('Aproximação de uma onda quadrada')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.grid()
plt.show()
