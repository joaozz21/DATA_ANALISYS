# %% [markdown]
# <a href="https://colab.research.google.com/github/joaozz21/BBC19JOAOHENRIQUE/blob/main/Tarefa9Jo%C3%A3oHenrique.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##João Henrique Alves de Oliveira

# %% [markdown]
# - **1)** Para este item você deverá usar o arquivo com a [porcentagem da população brasileira que é analfabeta, dividida por unidade da federação, de 1981 a 2014 (analfabetismo.csv, encontrado na pasta aula5/dados)](https://raw.githubusercontent.com/BMClab/BasesComputacionais/master/dados/analfabetismo.csv) (dados disponibilizados por Ipeadata).
#
#    + Faça um gráfico da taxa de analfabetismo em São Paulo em função do tempo (anos).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

populacao = pd.read_csv('https://raw.githubusercontent.com/BMClab/BasesComputacionais/master/dados/analfabetismo.csv')
populacao['Ano'] = pd.to_datetime(populacao['Ano'], format= '%Y')
saopaulo= populacao['São Paulo']
anos= populacao['Ano'].dt.year


plt.figure()
plt.plot(anos, saopaulo)
plt.grid()
plt.xlabel('Anos')
plt.ylabel('% de analfabetismo em São Paulo')
plt.show()
